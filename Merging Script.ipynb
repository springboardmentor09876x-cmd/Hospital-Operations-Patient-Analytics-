# %%
import pandas as pd
import os

folder = r"C:\Users\varun\Desktop\info dataset"

files_to_check = [
    "hospital_final_dataset.csv",
    "hospital_kpi_dataset.csv",
    "Hospital_Operations_Dataset.csv",
    "hospital data analysis.csv",
    "healthcare_dataset.csv",
    "healthcare_analytics_patient_flow_data.csv"
]

# Check CSV files
for f in files_to_check:
    full_path = os.path.join(folder, f)
    if os.path.exists(full_path):
        try:
            df = pd.read_csv(full_path, nrows=2)
            print(f"{f} columns:", df.columns.tolist()[:10], "... length:", len(df.columns))
        except Exception as e:
            print(f"Error reading {f}: {e}")
    else:
        print(f"{f} not found in {folder}")

# Check Excel files
excel_files = [
    "Synthetic_Hospital_Dataset.xlsx",
    "Merged_Hospital_Dataset.xlsx",
    "Hospital_Dataset.xlsx"
]

for f in excel_files:
    full_path = os.path.join(folder, f)
    if os.path.exists(full_path):
        try:
            xl = pd.ExcelFile(full_path)
            print(f"{f} sheets:", xl.sheet_names)
            df = pd.read_excel(full_path, nrows=2)
            print(f"  First sheet columns:", df.columns.tolist()[:10], "... length:", len(df.columns))
        except Exception as e:
            print(f"Error reading {f}: {e}")
    else:
        print(f"{f} not found in {folder}")
# Out:
# hospital_final_dataset.csv columns: ['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider', 'Billing Amount'] ... length: 23
# hospital_kpi_dataset.csv columns: ['Name', 'Age', 'Age Group', 'Gender', 'Blood Type', 'Date of Admission', 'Year', 'Month', 'Month Name', 'Quarter'] ... length: 38
# Hospital_Operations_Dataset.csv columns: ['Patient_ID', 'Age', 'Gender', 'Department', 'Diagnosis', 'Severity_Level', 'Admission_Date', 'Discharge_Date', 'Length_of_Stay_Days', 'Wait_Time_Minutes'] ... length: 15
# hospital data analysis.csv columns: ['Patient_ID', 'Age', 'Gender', 'Condition', 'Procedure', 'Cost', 'Length_of_Stay', 'Readmission', 'Outcome', 'Satisfaction'] ... length: 10
# healthcare_dataset.csv columns: ['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider', 'Billing Amount'] ... length: 15
# ...

# %%
df_synthetic = pd.read_excel(r"C:\Users\varun\Desktop\info dataset\Synthetic_Hospital_Dataset.xlsx", nrows=2)
print("Synthetic_Hospital_Dataset.xlsx columns:", df_synthetic.columns.tolist())
print("Length:", len(df_synthetic.columns))
# Out:
# Synthetic_Hospital_Dataset.xlsx columns: ['Hospital ID', 'Hospital Name', 'Hospital Type', 'City', 'State', 'Department', 'Department ID', 'Doctor', 'Nurses', 'Staff Count', 'Patient ID', 'Patient Name', 'Gender', 'Age', 'Admission Date', 'Discharge Date', 'Diagnosis', 'Treatment', 'Medication', 'Admission Type', 'Test Result', 'Blood Type', 'Beds Available', 'ICU Beds', 'Bed Number', 'Bed Occupied', 'Equipment', 'Length of Stay', 'Room No', 'Billing Amount', 'Insurance Provider', 'Readmission']
# Length: 32

# %%
import pandas as pd
import os

folder = r"C:\Users\varun\Desktop\info dataset"

# CSV files
for f in ['Hospital_Operations_Dataset.csv', 'hospital_kpi_dataset.csv', 'hospital_final_dataset.csv']:
    full_path = os.path.join(folder, f)
    if os.path.exists(full_path):
        try:
            df = pd.read_csv(full_path, nrows=0)
            cols = df.columns.tolist()
            matches = [c for c in cols if 'Derived' in c or 'Equipment' in c or 'Transfer' in c or 'Occupancy' in c]
            if matches:
                print(f"Matches in {f}:", matches)
        except Exception as e:
            print(f"Error reading {f}: {e}")
    else:
        print(f"{f} not found in {folder}")

# Excel files
for f in ['Merged_Hospital_Dataset.xlsx', 'Hospital_Dataset.xlsx']:
    full_path = os.path.join(folder, f)
    if os.path.exists(full_path):
        try:
            df = pd.read_excel(full_path, nrows=0)
            cols = df.columns.tolist()
            matches = [c for c in cols if 'Derived' in c or 'Equipment' in c or 'Transfer' in c or 'Occupancy' in c]
            if matches:
                print(f"Matches in {f}:", matches)
        except Exception as e:
            print(f"Error reading {f}: {e}")
    else:
        print(f"{f} not found in {folder}")
# Out:
# Matches in hospital_kpi_dataset.csv: ['Occupancy Rate (%)']
# Matches in Merged_Hospital_Dataset.xlsx: ['Equipment']
# Matches in Hospital_Dataset.xlsx: ['Equipment']

# %%
import pandas as pd
import os

folder = r"C:\Users\varun\Desktop\info dataset"

# Inspect all columns of Merged_Hospital_Dataset.xlsx
merged_path = os.path.join(folder, "Merged_Hospital_Dataset.xlsx")
if os.path.exists(merged_path):
    merged_cols = pd.read_excel(merged_path, nrows=0).columns.tolist()
    print("Merged_Hospital_Dataset.xlsx:", merged_cols)
    print("Length:", len(merged_cols))
else:
    print("Merged_Hospital_Dataset.xlsx not found in", folder)

# Inspect all columns of Hospital_Dataset.xlsx
hospital_path = os.path.join(folder, "Hospital_Dataset.xlsx")
if os.path.exists(hospital_path):
    hospital_cols = pd.read_excel(hospital_path, nrows=0).columns.tolist()
    print("Hospital_Dataset.xlsx:", hospital_cols)
    print("Length:", len(hospital_cols))
else:
    print("Hospital_Dataset.xlsx not found in", folder)
# Out:
# Merged_Hospital_Dataset.xlsx: ['Hospital ID', 'Hospital Name', 'City', 'State', 'Hospital Type', 'Beds Available', 'ICU Beds', 'Staff Count', 'Patient ID', 'Gender', 'Age', 'Admission Date', 'Discharge Date', 'Department', 'Diagnosis', 'Treatment', 'Doctor', 'Bed Number', 'Department.1', 'Doctors', 'Nurses', 'Equipment', 'Beds Occupied']
# Length: 23
# Hospital_Dataset.xlsx: ['Hospital ID', 'Hospital Name', 'City', 'State', 'Hospital Type', 'Beds Available', 'ICU Beds', 'Staff Count', 'Patient ID', 'Gender', 'Age', 'Admission Date', 'Discharge Date', 'Department', 'Diagnosis', 'Treatment', 'Doctor', 'Bed Number', 'Department.1', 'Doctors', 'Nurses', 'Equipment', 'Beds Occupied', 'Name', 'Blood Type', 'Medical Condition', 'Hospital', 'Insurance Provider', 'Billing Amount', 'Room Number', 'Admission Type', 'Medication', 'Test Results', 'Length of Stay', 'department_id', 'total_beds', 'total_staff', 'total_equipment', 'Admission Count', 'Is Readmission']
# Length: 40

# %%
import pandas as pd
import os

folder = r"C:\Users\varun\Desktop\info dataset"

# Load the synthetic dataset
df_synth_full = pd.read_excel(os.path.join(folder, "Synthetic_Hospital_Dataset.xlsx"))
print("Synthetic dataset shape:", df_synth_full.shape)

# Load the target dataset
df_target = pd.read_excel(os.path.join(folder, "Hospital_RawDataset_Updated.xlsx"))

# Inspect the remaining columns beyond the first 32
print("Target dataset extra columns:", df_target.columns[32:])
print(df_target[df_target.columns[32:]].head(5))
# Out:
# Synthetic dataset shape: (10000, 32)
# Target dataset extra columns: Index(['Dept_Bed_Capacity_Derived', 'Beds_Occupied_Count', 'Equipment ID',
#        'Equipment Number', 'Equipment Status', 'Equipment_Total_Inventory',
#        'Equipment_Usage_Duration_Hours', 'Transferred',
#        'Transfer_From_Department', 'Transfer_To_Department', 'Transfer_Date',
#        'Number_of_Transfers', 'Dept_ICU_Bed_Capacity_Derived',
#        'Dept_Staff_Capacity_Derived', 'Admissions_Rate_%_Derived',
#        'Staff_Utilization_%_Derived', 'Bed_Occupancy_Rate_%'],
#       dtype='object')
#    Dept_Bed_Capacity_Derived  Beds_Occupied_Count Equipment ID  \
# 0                        496                    1      EQ00001
# 1                        479                    1      EQ00002
# 2                        495                    1      EQ00003
# 3                        500                    2      EQ00004
# 4                        495                    3      EQ00005
#
# ...

# %%
import pandas as pd
import os

folder = r"C:\Users\varun\Desktop\info dataset"

print("Loading base dataset...")
df_base = pd.read_excel(os.path.join(folder, "Synthetic_Hospital_Dataset.xlsx"))

print("Loading updated operational/derived metrics...")
df_updated = pd.read_excel(os.path.join(folder, "Hospital_RawDataset_Updated.xlsx"))

derived_columns = [
    'Patient ID', 
    'Dept_Bed_Capacity_Derived', 'Beds_Occupied_Count', 'Equipment ID', 
    'Equipment Number', 'Equipment Status', 'Equipment_Total_Inventory', 
    'Equipment_Usage_Duration_Hours', 'Transferred', 'Transfer_From_Department', 
    'Transfer_To_Department', 'Transfer_Date', 'Number_of_Transfers', 
    'Dept_ICU_Bed_Capacity_Derived', 'Dept_Staff_Capacity_Derived', 
    'Admissions_Rate_%_Derived', 'Staff_Utilization_%_Derived', 'Bed_Occupancy_Rate_%'
]

df_base['Patient ID'] = df_base['Patient ID'].astype(str).str.strip()
df_updated['Patient ID'] = df_updated['Patient ID'].astype(str).str.strip()

df_derived_subset = df_updated[derived_columns]

print("Merging datasets...")
df_final = pd.merge(df_base, df_derived_subset, on='Patient ID', how='left')

final_column_order = [
    'Hospital ID', 'Hospital Name', 'Hospital Type', 'City', 'State', 
    'Department', 'Department ID', 'Doctor', 'Nurses', 'Staff Count', 
    'Patient ID', 'Patient Name', 'Gender', 'Age', 'Admission Date', 
    'Discharge Date', 'Diagnosis', 'Treatment', 'Medication', 'Admission Type', 
    'Test Result', 'Blood Type', 'Beds Available', 'ICU Beds', 'Bed Number', 
    'Bed Occupied', 'Equipment', 'Length of Stay', 'Room No', 'Billing Amount', 
    'Insurance Provider', 'Readmission', 'Dept_Bed_Capacity_Derived', 
    'Beds_Occupied_Count', 'Equipment ID', 'Equipment Number', 'Equipment Status', 
    'Equipment_Total_Inventory', 'Equipment_Usage_Duration_Hours', 'Transferred', 
    'Transfer_From_Department', 'Transfer_To_Department', 'Transfer_Date', 
    'Number_of_Transfers', 'Dept_ICU_Bed_Capacity_Derived', 
    'Dept_Staff_Capacity_Derived', 'Admissions_Rate_%_Derived', 
    'Staff_Utilization_%_Derived', 'Bed_Occupancy_Rate_%'
]

df_final = df_final[final_column_order]

output_filename = os.path.join(folder, "Final_Hospital_Dataset.xlsx")
print(f"Exporting to {output_filename}...")
df_final.to_excel(output_filename, index=False)
print("Processing successfully completed!")
# Out:
# Loading base dataset...
# Loading updated operational/derived metrics...
# Merging datasets...
# Exporting to C:\Users\varun\Desktop\info dataset\Final_Hospital_Dataset.xlsx...
# Processing successfully completed!
